# %% [markdown]
# ### 使用 request & bs4
# 額外新增 - 相同書名給予隨機ID

# %%
import os
import re
import random
import requests
from bs4 import BeautifulSoup as bs


Link = 'https://www.gutenberg.org'
chineseBooksPageURL = f'{Link}/browse/languages/zh'

folderPath = 'Gutenberg_ChineseBooks_v2.0'
if not os.path.exists(folderPath):
    os.makedirs(folderPath)

titleList = []
sameName_Key = 1

def GetAllBooksURL():
    res = requests.get(chineseBooksPageURL)
    soup = bs(res.text,'lxml')

    bookList = []
    booksName = soup.select('li > a[href]')
    
    for info in booksName:
        # 砍掉前後空白
        booksTitle = info.text.strip()
        # 中文正規表達式
        chineseRegex = r'[\u4e00-\u9fff]'

        # 若有中文則加入書單
        if re.search(chineseRegex,booksTitle) != None:
            bookList.append(
                {
                    "Title" : booksTitle,
                    "URL" : Link + info['href']
                }
            )
    
    return bookList

def getBooksInfo(book):
    global sameName_Key
    # 取得書本網頁
    res = requests.get(book["URL"])
    soup = bs(res.text,'lxml')

    # 取得書本內文連結
    bookLink = soup.find('a', text = 'Plain Text UTF-8')

    downloadLink = Link + bookLink['href']
    bookInfo = requests.get(downloadLink)

    # 避免windows存檔及部分特殊字元
    specialText = r'[<>:\"/\\|?*\—\-=+\~`\']+|\s+'
    file_title = re.sub(specialText, "_", book['Title'])

    # 若檔名相同，給與一個隨機值附加在檔名
    if file_title in titleList:
        # 給 100~999 降低重複機率
        sameName_Key = random.randint(100,1000)
        file_title = file_title + f"_RID_{sameName_Key}"
    titleList.append(file_title)
    file_path = os.path.join(folderPath, f"{file_title}.txt")


    with open(file_path , 'wb') as f:
        f.write(bookInfo.content)

    chineseText = []
    onlyChineseRegex = r"^\s|\u3000*[\u4e00-\u9fa5，。！？、；：「」『』（）《》〈〉…—\s]*$"
    with open(file_path,'r',encoding='utf-8') as f:
        for i in f.readlines():
            if re.match(onlyChineseRegex,i):
                chineseText.append(i)

    with open(file_path, 'w', encoding='utf-8') as f:
        for text in chineseText:
            f.write(text)
        
    print(f"已下載 {file_title}")


books = GetAllBooksURL()
for b in books:
    getBooksInfo(b)

print(f"已下載{len(books)}本書")
# Out:
# C:\Users\bob01\AppData\Local\Temp\ipykernel_26844\3294336760.py:49: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   bookLink = soup.find('a', text = 'Plain Text UTF-8')
# 已下載 豆棚閒話
# 已下載 戲中戲
# 已下載 比目魚
# 已下載 比目魚_RID_398
# 已下載 三字經
# 已下載 山水情
# 已下載 山海經
# 已下載 施公案
# 已下載 施公案_RID_963
# 已下載 易經
# 已下載 木蘭奇女傳
# 已下載 海公案
# 已下載 燕丹子
# 已下載 狄公案
# 已下載 百家姓
# 已下載 禮記
# 已下載 綠牡丹
# 已下載 詩經
# 已下載 麟兒報
# 已下載 天豹圖
# 已下載 梁公九諫
# 已下載 長恨歌
# 已下載 李娃傳
# 已下載 玉樓春
# 已下載 漢書
# 已下載 引鳳蕭
# 已下載 今古奇觀
# 已下載 後西游記
# 已下載 飛跎全傳
# 已下載 佛說四十二章經
# 已下載 紅樓夢
# 已下載 洛神賦
# 已下載 晁氏儒言_一卷
# 已下載 水滸後傳
# 已下載 幼學瓊林
# 已下載 治世餘聞
# 已下載 琵琶記
# 已下載 雪月梅傳
# 已下載 龍川詞
# 已下載 三國志
# 已下載 隋唐演義
# 已下載 論語
# 已下載 滬語開路___Conversational_Exercises_in_the_Shanghai_Dialect
# 已下載 白圭志
# 已下載 孟子字義疏證
# 已下載 安樂集
# 已下載 鄧析子
# 已下載 醉醒石
# 已下載 唐鍾馗平鬼傳
# 已下載 春秋繁露
# 已下載 虬髯客傳
# 已下載 吳船錄
# 已下載 星槎勝覽
# 已下載 星槎勝覽_RID_503
# 已下載 喻世明言
# 已下載 平妖傳
# 已下載 東周列國志
# 已下載 警世通言
# 已下載 醒世恆言
# 已下載 封氏聞見記
# 已下載 白圭志_RID_188
# 已下載 搜神記
# 已下載 搜神記_volume_11_14
# 已下載 搜神記_volume_1_3
# 已下載 搜神記_volume_15_17
# 已下載 搜神記_volume_18_20
# 已下載 搜神記_volume_4_10
# 已下載 琵琶記_RID_442
# 已下載 抱朴子
# 已下載 西京雜記
# 已下載 幽明錄
# 已下載 明鏡公案
# 已下載 公孫龍子
# 已下載 竇娥冤
# 已下載 竇娥寃
# 已下載 管子
# 已下載 管子___Volume_01___Chapters_1_5
# 已下載 管子___Volume_02___Chapters_6_10
# 已下載 鬼谷子
# 已下載 鬼谷子_RID_416
# 已下載 穆天子传
# 已下載 漢武帝別國洞冥記
# 已下載 日知錄
# 已下載 海上花列傳
# 已下載 韩非子
# 已下載 風月夢
# 已下載 韓詩外傳
# 已下載 韓詩外傳,_Complete
# 已下載 韓詩外傳,_Vol._1_2
# 已下載 韓詩外傳,_Vol._3_4
# 已下載 韓詩外傳,_Vol._5_6
# 已下載 韓詩外傳,_Vol._7_8
# 已下載 韓詩外傳,_Vol._9_10
# 已下載 唐诗三百首
# 已下載 長生殿
# 已下載 菜根譚
# 已下載 菜根譚前後集
# 已下載 天豹圖_RID_636
# 已下載 筠州黃檗山斷際禪師傳法心要
# 已下載 山水小牘
# 已下載 高士傳
# 已下載 金剛般若波羅蜜經
# 已下載 天妃顯聖錄
# 已下載 三略
# 已下載 明夷待訪錄
# 已下載 鹽鐵論
# 已下載 一枕奇
# 已下載 六祖壇經
# 已下載 臺灣外紀
# 已下載 賈誼新書
# 已下載 金石緣
# 已下載 閱微草堂筆記
# 已下載 醒夢駢言
# 已下載 孔叢子
# 已下載 小爾雅
# 已下載 續世說
# 已下載 桃花扇
# 已下載 金剛般若波羅蜜經_RID_719
# 已下載 補紅樓夢
# 已下載 老子
# 已下載 道德經
# 已下載 臺灣通史_唐山過海的故事
# 已下載 李太白集
# 已下載 李太白集_RID_702
# 已下載 官場現形記
# 已下載 官場現形記_RID_134
# 已下載 官場現形記_RID_811
# 已下載 文明小史
# 已下載 海公案_RID_974
# 已下載 孫子算經
# 已下載 列子
# 已下載 脾胃論
# 已下載 李賀詩選
# 已下載 文心雕龍
# 已下載 二刻拍案惊奇
# 已下載 二刻拍案驚奇
# 已下載 初刻拍案驚奇
# 已下載 殺子報
# 已下載 天妃顯聖錄_RID_250
# 已下載 西海紀遊草
# 已下載 西海紀遊草_RID_330
# 已下載 漱玉詞
# 已下載 鏡花緣
# 已下載 鏡花緣_RID_904
# 已下載 李義山詩集
# 已下載 天豹圖_RID_522
# 已下載 梁公九諫_RID_701
# 已下載 淮南子
# 已下載 天豹圖_RID_454
# 已下載 老殘遊記
# 已下載 老殘遊記_RID_475
# 已下載 老殘遊記續集
# 已下載 海島算經
# 已下載 郁離子
# 已下載 人物志
# 已下載 隋唐嘉話
# 已下載 大唐新語
# 已下載 列仙傳
# 已下載 列女傳
# 已下載 新序
# 已下載 說苑
# 已下載 說苑,_Volume_13_16
# 已下載 說苑,_Volume_1_4
# 已下載 說苑,_Volume_17_20
# 已下載 說苑,_Volume_5_8
# 已下載 說苑,_Volume_9_12
# 已下載 文心雕龍_RID_475
# 已下載 西京雜記_RID_750
# 已下載 舊唐書
# 已下載 世說新語
# 已下載 幽明錄_RID_649
# 已下載 樂章集
# 已下載 斬鬼傳
# 已下載 斬鬼傳_RID_681
# 已下載 夢中緣
# 已下載 合錦回文傳
# 已下載 無聲戲
# 已下載 肉蒲團
# 已下載 閒情偶寄
# 已下載 闲情偶寄
# 已下載 弟子規
# 已下載 天豹圖_RID_261
# 已下載 庚巳編
# 已下載 呻吟語
# 已下載 三國志演義
# 已下載 平妖傳_RID_494
# 已下載 平妖傳_RID_384
# 已下載 殘唐五代史演義傳
# 已下載 粉妝樓
# 已下載 粉妝樓1_10回
# 已下載 粉妝樓11_20回
# 已下載 粉妝樓21_30回
# 已下載 粉妝樓31_40回
# 已下載 粉妝樓41_50回
# 已下載 粉妝樓51_60回
# 已下載 粉妝樓61_70回
# 已下載 粉妝樓71_80回
# 已下載 粉妝樓全傳
# 已下載 說唐
# 已下載 文心雕龍_RID_618
# 已下載 常言道
# 已下載 大唐三藏取經詩話
# 已下載 六韜
# 已下載 癡人說夢記
# 已下載 癡人說夢記_RID_416
# 已下載 封神演義
# 已下載 中國小說史略
# 已下載 南腔北調集
# 已下載 吶喊
# 已下載 徬徨
# 已下載 朝花夕拾
# 已下載 狂人日記
# 已下載 狂人日記_RID_147
# 已下載 野草
# 已下載 阿Ｑ正傳
# 已下載 文子
# 已下載 老學庵筆記
# 已下載 茶經
# 已下載 茶經_RID_619
# 已下載 近思錄
# 已下載 瀛涯勝覽
# 已下載 瀛涯勝覽_RID_101
# 已下載 漢宮秋
# 已下載 孟子
# 已下載 東京夢華錄
# 已下載 白兔記
# 已下載 好逑傳
# 已下載 御製廣寒殿記
# 已下載 墨子
# 已下載 西湖佳話
# 已下載 癡人福
# 已下載 公墓
# 已下載 飲水詞集
# 已下載 春柳鶯
# 已下載 六一詞
# 已下載 歸田錄
# 已下載 三國志_RID_794
# 已下載 蜀碧
# 已下載 九尾狐
# 已下載 聊齋志異
# 已下載 醒世姻緣
# 已下載 南部新書
# 已下載 東度記
# 已下載 金雲翹傳
# 已下載 拾遺記
# 已下載 負曝閒談
# 已下載 滬語開路___Conversational_Exercises_in_the_Shanghai_Dialect_RID_441
# 已下載 燕子箋
# 已下載 佛說無量壽經
# 已下載 蕉葉帕
# 已下載 商君書
# 已下載 商子
# 已下載 俗話傾談
# 已下載 慎子
# 已下載 浮生六記
# 已下載 枕中記
# 已下載 夢溪筆談
# 已下載 夢溪筆談,_Volume_01_06
# 已下載 夢溪筆談,_Volume_01_26
# 已下載 夢溪筆談,_Volume_07_10
# 已下載 夢溪筆談,_Volume_11_16
# 已下載 夢溪筆談,_Volume_17_21
# 已下載 夢溪筆談,_Volume_22_26
# 已下載 諧鐸
# 已下載 六祖壇經_RID_613
# 已下載 幽閨記
# 已下載 水滸傳
# 已下載 文子_RID_851
# 已下載 三俠五義
# 已下載 史記
# 已下載 司馬法
# 已下載 灵历集光
# 已下載 灵历集光_RID_982
# 已下載 莊子的故事
# 已下載 天工開物
# 已下載 歸蓮夢
# 已下載 錦香亭
# 已下載 杜陽雜編
# 已下載 斷鴻零雁記
# 已下載 北夢瑣言
# 已下載 兵法_(Bīng_Fǎ)
# 已下載 孫子兵法
# 已下載 孫子算經_RID_372
# 已下載 東坡志林
# 已下載 東坡樂府
# 已下載 水調歌頭
# 已下載 蘇洵集
# 已下載 孫子兵法道家新註解
# 已下載 牡丹亭
# 已下載 彭公案
# 已下載 五孝傳
# 已下載 搜神後記
# 已下載 搜神後記._Selections._1985
# 已下載 轟天雷
# 已下載 人間樂
# 已下載 定情人
# 已下載 平山冷燕
# 已下載 玉嬌梨
# 已下載 玉支机
# 已下載 玉雙魚
# 已下載 畫圖緣
# 已下載 石點頭
# 已下載 商界現形記
# 已下載 合錦回文傳_RID_196
# 已下載 玉蟾記
# 已下載 宋史
# 已下載 周髀算經
# 已下載 天豹圖_RID_171
# 已下載 孔雀東南飛
# 已下載 孝經
# 已下載 文子_RID_637
# 已下載 明鏡公案_RID_215
# 已下載 春秋配
# 已下載 梁公九諫_RID_222
# 已下載 爾雅
# 已下載 竹書紀年
# 已下載 黄帝宅經
# 已下載 大唐三藏取經詩話_RID_179
# 已下載 文淵閣四庫全書
# 已下載 本草備要
# 已下載 論衡
# 已下載 魏鄭公諫錄
# 已下載 人間詞話
# 已下載 大唐三藏取經詩話_RID_634
# 已下載 海國春秋
# 已下載 拾遺記_RID_381
# 已下載 冷眼观
# 已下載 竹齋集
# 已下載 西廂記
# 已下載 豔異編
# 已下載 分甘余話
# 已下載 劍俠傳
# 已下載 池北偶談
# 已下載 文中子中說
# 已下載 荀子集解
# 已下載 醒夢駢言_RID_905
# 已下載 豆棚閒話_RID_646
# 已下載 傳習錄
# 已下載 王陽明全集
# 已下載 故事新讀本__第一冊
# 已下載 三字經_RID_889
# 已下載 花外集
# 已下載 圍爐夜話
# 已下載 文中子中說_RID_357
# 已下載 御製廣寒殿記_RID_399
# 已下載 尉繚子
# 已下載 花月痕
# 已下載 花月痕_RID_951
# 已下載 明月台
# 已下載 兒女英雄傳
# 已下載 玉壺淸話
# 已下載 西遊記
# 已下載 古文觀止
# 已下載 青箱雜記
# 已下載 古文觀止_RID_734
# 已下載 海遊記
# 已下載 駐春園小史
# 已下載 九命奇冤
# 已下載 九命奇冤_RID_482
# 已下載 二十年目睹之怪現狀
# 已下載 二十年目睹之怪現狀_RID_218
# 已下載 恨海
# 已下載 情變
# 已下載 瞎騙奇聞
# 已下載 胡涂世界
# 已下載 貞觀政要
# 已下載 貞觀政要_RID_804
# 已下載 中國十大禁書之國色天香
# 已下載 儒林外史
# 已下載 楊家將
# 已下載 明鏡公案_RID_886
# 已下載 五色石
# 已下載 快士傳
# 已下載 飛龍全傳
# 已下載 風月鑒
# 已下載 拾遺記_RID_527
# 已下載 古詩十九首
# 已下載 金瓶梅
# 已下載 滿江紅
# 已下載 宛如約
# 已下載 歡喜冤家
# 已下載 文子_RID_497
# 已下載 八段錦
# 已下載 辛棄疾詞選
# 已下載 唐才子傳
# 已下載 楊家將_RID_737
# 已下載 楊家將_RID_108
# 已下載 楊家將演義
# 已下載 夜雨秋燈錄
# 已下載 雙鳳奇緣
# 已下載 徐霞客遊記
# 已下載 玉台新詠
# 已下載 申鑒
# 已下載 李太白集_RID_323
# 已下載 李太白集_RID_747
# 已下載 蘇洵集_RID_109
# 已下載 玉梨魂
# 已下載 韓湘子全傳
# 已下載 鬼谷四友志
# 已下載 畫圖緣_RID_332
# 已下載 方言
# 已下載 漢書_RID_747
# 已下載 巧聯珠
# 已下載 幻中游
# 已下載 滄浪詩話
# 已下載 顔氏家訓
# 已下載 顔氏家訓_RID_545
# 已下載 顔氏家訓_RID_659
# 已下載 顔氏家訓___Volume_01_and_02
# 已下載 顔氏家訓___Volume_03_and_04
# 已下載 顔氏家訓___Volume_05_and_06
# 已下載 顔氏家訓___Volume_07
# 已下載 竹葉亭雜記
# 已下載 豐收
# 已下載 蘭花夢奇傳
# 已下載 尹文子
# 已下載 關尹子
# 已下載 黃繡球
# 已下載 鄰女語
# 已下載 合浦珠
# 已下載 珍珠舶
# 已下載 子不語
# 已下載 續子不語
# 已下載 隨園詩話
# 已下載 鶯鶯傳
# 已下載 青樓夢
# 已下載 沉沦
# 已下載 滿江紅_RID_526
# 已下載 耳食錄
# 已下載 桯史
# 已下載 蜃樓志
# 已下載 五鳳吟
# 已下載 警悟鐘
# 已下載 蕩寇志
# 已下載 裨海紀遊
# 已下載 孽海花
# 已下載 幽夢影
# 已下載 幽夢影_RID_369
# 已下載 幽夢影___Part_1
# 已下載 幽夢影___Part_2
# 已下載 西湖夢尋
# 已下載 陶庵夢憶
# 已下載 列仙傳_RID_908
# 已下載 何典
# 已下載 棋經
# 已下載 括異志
# 已下載 杜騙新書
# 已下載 張載集
# 已下載 傷寒論
# 已下載 朝野僉載
# 已下載 遊仙窟
# 已下載 遊仙窟_RID_423
# 已下載 花間集
# 已下載 吳越春秋
# 已下載 甌北詩話
# 已下載 明皇雜錄
# 已下載 詩品
# 已下載 詩品_RID_462
# 已下載 周禮
# 已下載 西湖二集
# 已下載 千字文
# 已下載 千字文_RID_787
# 已下載 千字文_RID_536
# 已下載 雞肋編
# 已下載 出師表
# 已下載 牛郎織女傳
# 已下載 中庸_章句
# 已下載 大學_章句
# 已下載 近思錄_RID_232
# 已下載 近思錄_RID_145
# 已下載 朱子治家格言
# 已下載 歐遊雜記
# 已下載 樂章集_RID_959
# 已下載 狐狸緣全傳
# 已下載 清代野记
# 已下載 風流悟
# 已下載 國語
# 已下載 左傳
# 已下載478本書
